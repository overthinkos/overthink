# %% [markdown]
# # Concurrency test seed
#
# This is the starting state for every scenario. The harness's `before_each` resets the notebook to this content.

# %%
x = 0  # baseline cell — many scenarios edit this index

# %%
y = 0  # second baseline cell — used in disjoint-cells scenarios
